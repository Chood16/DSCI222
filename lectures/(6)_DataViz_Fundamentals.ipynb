# %% [markdown]
# <a href="https://colab.research.google.com/github/Chood16/DSCI222/blob/main/lectures/(6)_DataViz_Fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fundamentals of Data Visualization, LaTeX & Text Rendering, and Common Misconceptions

# %% [markdown]
# ## Fundamentals of Data Visualization
# Data visualization is the graphical representation of information and data. By using visual elements like charts, graphs, and maps, data visualization tools provide an accessible way to see and understand trends, outliers, and patterns in data.
#
# **Advantages**
# * Easily sharing information.
# * Interactively explore opportunities.
# * Visualize patterns and relationships.
#
# **Disadvantages**
# * Biased or inaccurate information.
# * Correlation doesn’t always mean causation.
# * Core messages can get lost in translation.

# %% [markdown]
# ### Plots

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# forces random numbers to be the same each time
np.random.seed(42)

# sets 100 dots per in for resolution
plt.figure(dpi=100)

sample_size = 150
sample_mean = 0
sample_sd = 10
x1 = np.random.normal(sample_mean, sample_sd, sample_size)
x2 = np.linspace(-30,30,1000)
y1 = x1**2 + 2 * x1 + np.random.normal(0, 40, sample_size)
y2 = x2**2 + 2 * x2 + 40

# Creates plots
plt.plot(x1, y1, marker='.', linestyle='')
plt.plot(x2, y2)

# Displays plots
plt.show()

# %% [markdown]
# #### How can we add more information?

# %% [markdown]
# * Title
# * Labels
# * Grid
# * Descriptive Text

# %%
plt.plot(x1, y1, marker='.', linestyle='')
plt.plot(x2, y2)


plt.title("Relationship Example: y vs. x")
plt.xlabel("x (units)")
plt.ylabel("f(x) (units)")
plt.text(-15, 620, 'Equation: f(x) = x^2 + 2x - 5') #doesn't look too good
plt.grid(True)
plt.show()

# %% [markdown]
# Let's put it in MathText (LaTeX-like) by using $$

# %%
plt.plot(x1, y1, marker='.', linestyle='')
plt.plot(x2, y2)

plt.title("Relationship Example: y vs. x")
plt.xlabel("$x$ (units)")
plt.ylabel("$f(x)$ (units)")

# In Matplotlib, the $ symbols tell it to interpret the enclosed text using LaTeX-style math formatting.
plt.text(-15, 620, 'Equation: $f(x) = x^2 + 2x - 5$')
plt.grid(True)
plt.show()

# %% [markdown]
# #### How can we make this look even nicer?

# %% [markdown]
# * Change font
# * Add Colors
# * ...More style parameters

# %%
# Let's see what fonts we have natively supported
import matplotlib.font_manager as fm
print([f.name for f in fm.fontManager.ttflist])
# Out:
# ['STIXNonUnicode', 'DejaVu Serif', 'DejaVu Serif Display', 'DejaVu Sans Mono', 'DejaVu Sans Display', 'STIXSizeFourSym', 'cmmi10', 'STIXSizeOneSym', 'DejaVu Serif', 'STIXSizeTwoSym', 'STIXGeneral', 'STIXSizeOneSym', 'STIXNonUnicode', 'cmtt10', 'STIXSizeThreeSym', 'DejaVu Serif', 'STIXNonUnicode', 'DejaVu Sans', 'STIXSizeTwoSym', 'DejaVu Sans', 'DejaVu Sans Mono', 'cmex10', 'STIXNonUnicode', 'cmss10', 'STIXSizeFourSym', 'STIXGeneral', 'DejaVu Serif', 'STIXSizeFiveSym', 'cmb10', 'STIXGeneral', 'cmr10', 'DejaVu Sans Mono', 'DejaVu Sans', 'STIXGeneral', 'DejaVu Sans Mono', 'DejaVu Sans', 'cmsy10', 'STIXSizeThreeSym', 'Liberation Mono', 'Liberation Sans', 'Humor Sans', 'Liberation Mono', 'Liberation Sans Narrow', 'Liberation Serif', 'Liberation Serif', 'Liberation Sans', 'Liberation Sans Narrow', 'Liberation Serif', 'Liberation Sans', 'Liberation Sans', 'Liberation Mono', 'Liberation Serif', 'Liberation Sans Narrow', 'Liberation Sans Narrow', 'Liberation Mono']

# %%
plt.plot(x1, y1, marker='.', linestyle='')
plt.plot(x2, y2)

# We can change things like font at the text element level
plt.text(-15, 620, 'Equation: $f(x) = x^2 + 2x - 5$', fontname="cmmi10")
plt.title("Relationship Example: y vs. x")
plt.xlabel("$x$ (units)")
plt.ylabel("$f(x)$ (units)")
plt.grid(True)
plt.show()

# %%
# or we can change it globally

# Computer Modern (cm) is similar to LaTeX font
# rcParams is the style/config dictionary for all plots: fonts, figure size, colors, DPI, line width, etc
plt.rcParams.update({
    "font.family": "serif",
    "mathtext.fontset": "cm",
})

plt.plot(x1, y1, marker='.', linestyle='')
plt.plot(x2, y2)

plt.text(-15, 620, 'Equation: $f(x) = x^2 + 2x - 5$')
plt.title("Relationship Example: y vs. x")
plt.xlabel("$x$ (units)")
plt.ylabel("$f(x)$ (units)")
plt.grid(True)
plt.show()

# %% [markdown]
# We can also use LaTeX font by installing it

# %%
# You could also install LaTex and actually use the font
# This check to see where (if anywhere) LaTeX is installed
# In Colab, ! lets you run shell (terminal) commands from inside a notebook
# !whereis latex
# Out:
# latex:

# %%
# To install latex packages (this may take a while)
# we know ! accesses the terminal
# apt: Advanced Package Tool, installs, removes, updates, and manages packages
# intall: installs
# texlive-fonts-recommendedL: common LaTeX fonts
# texlive-fonts-extra: even more LaTeX fonts
# cm-super: the font we are acutally looking for
# dvipng: converts LaTeX DVI files into PNG images for rendering
# !apt install texlive-fonts-recommended texlive-fonts-extra cm-super dvipng
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   cm-super-minimal dvisvgm fonts-adf-accanthis fonts-adf-berenis
#   fonts-adf-gillius fonts-adf-universalis fonts-cabin fonts-cantarell
#   fonts-comfortaa fonts-croscore fonts-crosextra-caladea
#   fonts-crosextra-carlito fonts-dejavu-core fonts-dejavu-extra
#   fonts-droid-fallback fonts-ebgaramond fonts-ebgaramond-extra
#   fonts-font-awesome fonts-freefont-otf fonts-freefont-ttf fonts-gfs-artemisia
#   fonts-gfs-complutum fonts-gfs-didot fonts-gfs-neohellenic fonts-gfs-olga
#   fonts-gfs-solomos fonts-go fonts-junicode fonts-lato fonts-linuxlibertine
#   fonts-lmodern fonts-lobster fonts-lobstertwo fonts-noto-color-emoji
#   fonts-noto-core fonts-noto-mono fonts-oflb-asana-math fonts-open-sans
#   fonts-roboto-unhinted fonts-sil-charis fonts-sil-gentium
# ...

# %%
# To activate text rendering by LaTex
plt.rcParams.update({
    "text.usetex": True, # Use LaTeX engine instead of MathText
    "font.family": "monospace",
    "font.monospace": 'Computer Modern Typewriter'
})

# %%
plt.plot(x1, y1, marker='.', linestyle='')
plt.plot(x2, y2)

plt.text(-15, 620, 'Equation: $f(x) = x^2 + 2x - 5$')
plt.title("Relationship Example: y vs. x")
plt.xlabel("$x$ (units)")
plt.ylabel("$f(x)$ (units)")
plt.grid(True)
plt.show()

# %% [markdown]
# What other parameters can we change? [Use the API Reference](https://matplotlib.org/stable/users/explain/customizing.html)!!!

# %%
# Plot
plt.plot(
    x1, y1,
    marker='o',             # marker type
    markersize=6,           # marker size
    markerfacecolor='#EEB111', # marker fill color
    markeredgewidth=1.5,    # marker border width
    markeredgecolor='#002855', # marker border color
    linestyle='',           # line style
    alpha=0.8,              # transparency
    label='Points',         # legend label
)

# Plot text, title, and labels
plt.text(-10, 400,'Equation: $f(x) = x^2 + 2x - 5$',
    fontsize=12, # font size
    color='#002855',
    alpha=0.9,
    rotation=25, # display angle
    ha='left',  # horizontal alignment
    va='center', # vertical alignment
)

plt.title("Relationship Example: y vs. x",
    fontsize=18,
    fontstyle='italic',
    fontweight='bold',
    color='#002855',
    loc='center',
    pad=10
)

plt.xlabel(
    "$x$ (units)",
    fontsize=14,
    color='#002855',
    labelpad=10
)
plt.ylabel(
    "$f(x)$ (units)",
    fontsize=14,
    color='#002855',
    labelpad=10
)

# Grid and legend
plt.grid(True,
         which='both',
         linestyle='--',
         linewidth=0.7,
         color='gray',
         alpha=0.5)

plt.legend(fontsize=12,
           loc='upper center',
           facecolor='lightgray',
           edgecolor='black')

plt.plot(x2, y2)

plt.show()

# %% [markdown]
# ### Scatterplots

# %%
# How to open data in Google Colab from your Google Drive
# ---------------------------------

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Let's search our terminal to locate the file

# !ls "/content/drive/MyDrive/Teaching Courses/"
# Out:
#  AoPS	    'Math 122'	'Math 150'  'Math 251'	'Stat 211'
# 'DSCI 222'  'Math 126'	'Math 155'  'Math 261'
# 'Math 121'  'Math 128'	'Math 156'   Pierpont

# %%
import pandas as pd

# reading the database
path = "/content/drive/MyDrive/Teaching Courses/DSCI 222/DataSets/Restaurant.csv"
data = pd.read_csv(path)

# printing the top 5 rows
display(data.head(5))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Scatter Plot
# ---------------------------------
import matplotlib.pyplot as plt
# Scatter plot with day against tip
x = data['day']
y = data['tip']
coloring = data['size']
sizing = data['total_bill']
plt.scatter(x, y, c=coloring, s=sizing, cmap='plasma')

# To add the Title to the Plot
plt.title("Scatter Plot")

# To set the X and Y labels
plt.xlabel('Day')
plt.ylabel('Tip')

# To include the colorbar
plt.colorbar()

plt.show()

# %% [markdown]
# ### Lines

# %%
# The Drunkards Walk

# Walking home, taking 500 steps
t = range(0, 500)

each_step = np.random.normal(0, 1, 500)
distance_from_bar = np.cumsum(each_step)

plt.plot(t, distance_from_bar)
plt.title("Where is our Friend? Using plt")
plt.xlabel("Steps")
plt.ylabel("Location")
plt.show()

# %%
# LinePlot via Seaborn
import pandas as pd
import seaborn as sns

# Seaborn is a Python data visualization library built on top of Matplotlib.
# It’s designed to make creating statistical graphics easier and prettier.
# Supports dataframes, prepackaged stylings, confidence intervals, etc.

# Seaborn utilizes data in DataFrame form
# Let's put steps and disance from bar into a df using dictionaries
df = pd.DataFrame({"Steps": t, "Location": distance_from_bar})

# Seaborn stylings
'''sns.set_style("darkgrid")  # grid background
sns.set_palette("pastel")   # color palette
sns.set_context("talk")     # makes fonts bigger for presentations'''
# sns.reset_defaults()

sns.lineplot(x="Steps", y="Location", data=df)
plt.title("Where is our Friend? Using Seaborn")
plt.show()

# %% [markdown]
# ### Histograms

# %%
# Making the Car Sale

# It's reasonable to use a gamma distribution to model time between sales
# The Gamma distribution is often used to model waiting times or non-negative skewed data.

customers_per_car_sold = 7 #
min_between_customers = 45
sales_per_year = 1000

car_data = np.random.gamma(shape=customers_per_car_sold,
                       scale=min_between_customers,
                       size=sales_per_year)

print(car_data[:5])

plt.hist(car_data, bins=20, edgecolor='black')
plt.title("Average Time Between Car Sales")
plt.xlabel("Minutes")
plt.ylabel("Sales per Bin")
plt.show()
# Out:
# [418.71178235 270.69889593 541.31292795 259.93100179 258.03328812]

# %%
# Histoplot via Seaborn
# ----------------------------

# kde: Kernal Density Estimate: Smooth curve of data
# hue: splits data based on given parameter

sns.histplot(x='total_bill', data=data, kde=True, hue='sex')

plt.show()

# %% [markdown]
# ### Heatmaps

# %%
# Histoplot via Seaborn
# ----------------------------

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Column names
col_names = ['Sepal_Length', 'Sepal_Width', 'Petal_Length', 'Petal_Width', 'Species']

# Load the dataset from UCI repository
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
iris = pd.read_csv(url, header=None, names=col_names)
print(iris.head(5))
# Select only numeric columns using .select_dtypes
numeric_cols = iris.select_dtypes(include='number')
print(numeric_cols.head(5))

# Compute correlation matrix (r value from stats)
# https://en.wikipedia.org/wiki/Pearson_correlation_coefficient

# .corr() is a DataFrame method in pandas that calculates pairwise correlation
corr_matrix = numeric_cols.corr()

# Create heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix,
            annot=True,
            cmap='coolwarm',
            fmt='.2f',
            linewidths=0.5,
            vmin=-1,
            vmax=1 )
plt.title('Correlation Matrix of Iris Dataset')
plt.show()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width      Species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %% [markdown]
# ## Visual Checklist
# - Is the **question** clear from the title/subtitle?
# - Are encodings **appropriate** for the data type?
# - Are axes **labeled**, units present, legends minimal, and annotations helpful?
# - Any **misleading scales**, truncated baselines, or overloaded color?
# - Can a reader **get the key takeaway in 5 seconds**?

# %% [markdown]
# ## Common Misconceptions & Pitfalls (with Fixes)
#
# 1. Don't use truncated axes
# 2. Reduce chartjunk; emphasize data, not effects.
# 3. Use labels/annotations; consider patterns/position for redundancy.
# 4. 3D distorts perception; use 2D unless spatial is the data.

# %% [markdown]
# ### Truncated vs. zero-baseline bars

# %%
import numpy as np
import matplotlib.pyplot as plt

cats = ["A","B","C","D"]
vals = np.array([48, 50, 52, 54])

# Misleading view (truncated)
plt.figure(figsize=(6,4))
plt.bar(cats, vals)
plt.ylim(47, 55)  # truncation exaggerates small differences
plt.title("Misleading: Truncated y-axis exaggerates differences")
plt.ylabel("Value")
plt.tight_layout()
plt.show()

# Proper baseline
plt.figure(figsize=(6,4))
plt.bar(cats, vals)
plt.ylim(0, 55)   # zero baseline
plt.title("Better: Bars with zero baseline")
plt.ylabel("Value")
plt.tight_layout()
plt.show()
