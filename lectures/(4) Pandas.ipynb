# %% [markdown]
# # Pandas

# %% [markdown]
# * Open-source Python library designed for working with relational or labeled data in an easy and intuitive way.
#
# * Built on top of NumPy, reusing and extending many of its data structures.
#
# * Provides powerful data structures (like DataFrame and Series) for manipulating numerical data and time series.
#
# * Offers high performance and productivity for data analysis tasks.
#
# * Commonly used in data science workflows alongside:
#
#   * Matplotlib for data visualization
#
#   * SciPy for statistical analysis
#
#   * Scikit-learn for machine learning
#
# * Enables seamless data handling, making it easier to clean, transform, and analyze datasets.

# %%
# To import libraries
import numpy as np
import pandas as pd

# %% [markdown]
# # Series

# %%
# To create Series
s = pd.Series([-5, 1.3, 21, 6, 3],
              index = ['a', 'b', 'c', 'd', 'e'])
print(s)
display(s)
# Out:
# a    -5.0
# b     1.3
# c    21.0
# d     6.0
# e     3.0
# dtype: float64
# a    -5.0
# b     1.3
# c    21.0
# d     6.0
# e     3.0
# dtype: float64

# %%
# You can call an element by their index
print(s['a'])

s['a'] = 5
s
# Out:
# -5.0
# a     5.0
# b     1.3
# c    21.0
# d     6.0
# e     3.0
# dtype: float64

# %%
# Don't forget to use copy!!!

s2 = s
s2['a'] = -5
display('s series updates as well:', s)

s2 = s.copy()
s2['a'] = 1111
display("Now that s2 was made as a copy, s won't change", s)
# Out:
# 's series updates as well:'
# a    -5.0
# b     1.3
# c    21.0
# d     6.0
# e     3.0
# dtype: float64
# "Now that s2 was made as a copy, s won't change"
# a    -5.0
# b     1.3
# c    21.0
# d     6.0
# e     3.0
# dtype: float64

# %%
# Conver to Numpy object
s.to_numpy()
# Out:
# array([-5. ,  1.3, 21. ,  6. ,  3. ])

# %%
# How to GET specific elements (e.g., 'e', 'd', 'c')?
s[["b", "d", "c"]]
# Out:
# b     1.3
# d     6.0
# c    21.0
# dtype: float64

# %%
# How to show all numbers above the mean?
s[s > s.mean()]
# Out:
# c    21.0
# d     6.0
# dtype: float64

# %%
# Can we perform operations (+, **, etc) on Series?
s1 = pd.Series(range(4), index = ["A", "B", "C", "D"], name = 'Series one')
display( s1 )
s2 = pd.Series(data = range(10, 14), index = ["B", "C", "D", "E"])
display( s2 )
# Out:
# A    0
# B    1
# C    2
# D    3
# Name: Series one, dtype: int64
# B    10
# C    11
# D    12
# E    13
# dtype: int64

# %%
#        ¿?
s1 + s2
# Out:
# A     NaN
# B    11.0
# C    13.0
# D    15.0
# E     NaN
# dtype: float64

# %%
# How to show the type of each instance in the Series ?
x = pd.Series(['A', 1, ["I", "AM", "A", "LIST"]])
x.map(type)
# Out:
# 0     <class 'str'>
# 1     <class 'int'>
# 2    <class 'list'>
# dtype: object

# %%
# Even more ...
x1 = pd.Series([1, 2, 3])
print(f"x1 dtype: {x1.dtype}")
print(f"x1 memory usage: {x1.memory_usage(deep=True)} bytes")
print("")
x2 = pd.Series([1, 2, "3"])
print(f"x2 dtype: {x2.dtype}")
print(f"x2 memory usage: {x2.memory_usage(deep=True)} bytes")
print("")
# Coerce the object series to int8
x3 = pd.Series([1, 2, "3"]).astype('int8')
print(f"x3 dtype: {x3.dtype}")
print(f"x3 memory usage: {x3.memory_usage(deep=True)} bytes")
# Out:
# x1 dtype: int64
# x1 memory usage: 156 bytes
#
# x2 dtype: object
# x2 memory usage: 262 bytes
#
# x3 dtype: int8
# x3 memory usage: 135 bytes

# %% [markdown]
# # Dataframes

# %%
# Test the next 5 different ways to create a DataFrame

# %%
# Dictionary <-- Most common for df
df = pd.DataFrame({"Name": ['Tom', 'Mike', 'Tiffany'], "Age": [7, 15, 3]})
display (df)

# List of lists <-- Very common as well
df = pd.DataFrame([['Tom', 7], ['Mike', 15], ['Tiffany', 3]], columns=['Name', 'Age'])
display (df)

# ndarray
df = pd.DataFrame(np.array([['Tom', 7], ['Mike', 15], ['Tiffany', 3]]), columns=['Name', 'Age'])
display (df)

# List of  Tuples
df = pd.DataFrame(zip(['Tom', 'Mike', 'Tiffany'], [7, 15, 3]), columns=['Name', 'Age'])
display (df)

# Series
df = pd.DataFrame({"Name": pd.Series(['Tom', 'Mike', 'Tiffany']), "Age": pd.Series([7, 15, 3])})
display (df)
# Out:
#       Name  Age
# 0      Tom    7
# 1     Mike   15
# 2  Tiffany    3
#       Name  Age
# 0      Tom    7
# 1     Mike   15
# 2  Tiffany    3
#       Name Age
# 0      Tom   7
# 1     Mike  15
# 2  Tiffany   3
#       Name  Age
# 0      Tom    7
# 1     Mike   15
# 2  Tiffany    3
#       Name  Age
# 0      Tom    7
# 1     Mike   15
# 2  Tiffany    3

# %%
# It includes Column names and the Index
df = pd.DataFrame({"Name": ['Tom', 'Mike', 'Tiffany'],
                   "Language": ['R', 'Python', 'Python'],
                   "Courses": [7, 15, 3]},
                  index = [777, 888, 999] )

display( df )
# Out:
#         Name Language  Courses
# 777      Tom        R        7
# 888     Mike   Python       15
# 999  Tiffany   Python        3

# %%
# It's always helpful to check the data types
df.map(type)
# Out:
#               Name       Language        Courses
# 777  <class 'str'>  <class 'str'>  <class 'int'>
# 888  <class 'str'>  <class 'str'>  <class 'int'>
# 999  <class 'str'>  <class 'str'>  <class 'int'>

# %%
# let's make them all strings
df = df.astype({'Name': 'string', 'Courses': 'string'})
df.map(type)
# Out:
#               Name       Language        Courses
# 777  <class 'str'>  <class 'str'>  <class 'str'>
# 888  <class 'str'>  <class 'str'>  <class 'str'>
# 999  <class 'str'>  <class 'str'>  <class 'str'>

# %%
# Show all observations/instances where their
# number of courses is greater than 5
# df[df['Courses'] > 5]
df[df['Courses'].astype('int16') > 5]
# Out:
#      Name Language Courses
# 777   Tom        R       7
# 888  Mike   Python      15

# %%
# Add the next row:
# Kate, Golang, 6, 4.0
# with index: 111

new_row = pd.DataFrame([{'Name':'Kate', 'Language': 'Golang', 'Courses': 6}], index = [111])
df = pd.concat([df, new_row])
display(df)
# Out:
#         Name Language Courses
# 777      Tom        R       7
# 888     Mike   Python      15
# 999  Tiffany   Python       3
# 111     Kate   Golang       6

# %%
# There's always more than one way to do it
new_row = {'Name':'Zefran', 'Language': 'Python', 'Courses': 5}
df.loc[len(df)] = new_row
display( df )

# To change the index value
df.rename( index = {df.index[-1] : 222}, inplace = True )
display( df )
# Out:
#         Name Language Courses
# 777      Tom        R       7
# 888     Mike   Python      15
# 999  Tiffany   Python       3
# 111     Kate   Golang       6
# 4     Zefran   Python       5
#         Name Language Courses
# 777      Tom        R       7
# 888     Mike   Python      15
# 999  Tiffany   Python       3
# 111     Kate   Golang       6
# 222   Zefran   Python       5

# %%
# Insert a column 'Credits' where Credits = Courses * 3

# It doesn't work as expected!!

df.assign(Credits = lambda x: x.Courses * 3)
# Out:
#         Name Language Courses Credits
# 777      Tom        R       7     777
# 888     Mike   Python      15  151515
# 999  Tiffany   Python       3     333
# 111     Kate   Golang       6      18
# 222   Zefran   Python       5      15

# %%
df = df.astype({'Courses': 'int16'})
df.map(type)
# Out:
#               Name       Language        Courses
# 777  <class 'str'>  <class 'str'>  <class 'int'>
# 888  <class 'str'>  <class 'str'>  <class 'int'>
# 999  <class 'str'>  <class 'str'>  <class 'int'>
# 111  <class 'str'>  <class 'str'>  <class 'int'>
# 222  <class 'str'>  <class 'str'>  <class 'int'>

# %%
# Attempt 2

df = df.assign(Credits = lambda x: x.Courses * 3)
display(df)

# Let's remove the column and try a different way
df = df.drop(columns='Credits')
display(df)

#Attempt 3
df['Credits'] = df['Courses'] * 3
display(df)
# Out:
#         Name Language  Courses  Credits
# 777      Tom        R        7       21
# 888     Mike   Python       15       45
# 999  Tiffany   Python        3        9
# 111     Kate   Golang        6       18
# 222   Zefran   Python        5       15
#         Name Language  Courses
# 777      Tom        R        7
# 888     Mike   Python       15
# 999  Tiffany   Python        3
# 111     Kate   Golang        6
# 222   Zefran   Python        5
#         Name Language  Courses  Credits
# 777      Tom        R        7       21
# 888     Mike   Python       15       45
# 999  Tiffany   Python        3        9
# 111     Kate   Golang        6       18
# 222   Zefran   Python        5       15

# %%
# Show all observations/instances where their
# number of courses is greater than 4
# when the language is Python
df[(df['Courses'] > 4) & (df['Language'] == 'Python')]
# Out:
#        Name Language  Courses  Credits
# 888    Mike   Python       15       45
# 222  Zefran   Python        5       15

# %%
# What if we want just the names of these students?

df[(df['Courses'] > 4) & (df['Language'] == 'Python')]['Name']
# Out:
# 888      Mike
# 222    Zefran
# Name: Name, dtype: object

# %%
# Create a dataset, fill out with random integer values [-7, 13),
# with 270 rows and 50 columns.
# The column names will follow the format:
# Col_1, Col_2, ... , Col_50
# The index values will follow the format:
# 2029-01-01, 2029-01-02, ..., 2029-09-27

# Random data
rnd_data = np.random.randint(-7, 13, (270, 50))
print(rnd_data.shape)

# Column names using list comprehension
dt_col = ['Col_'+str(i) for i in range(1,rnd_data.shape[1]+1)]


# Index
dt_idx = pd.date_range(start='2029-01-01', periods=rnd_data.shape[0], freq='D')
# dt_idx = pd.date_range(start='2029-01-01', end='2029-09-27', freq='D')

df_rnd = pd.DataFrame(rnd_data, index = dt_idx, columns = dt_col)
display( df_rnd )
display( df_rnd.head())
# Out:
# (270, 50)
#             Col_1  Col_2  Col_3  Col_4  Col_5  Col_6  Col_7  Col_8  Col_9  \
# 2029-01-01      9     11      3     -7      2      9     -5      8      4
# 2029-01-02      4     12     -4     11     -3      4     -6      3     11
# 2029-01-03      5      8      9      9      7     -4     -1      3      8
# 2029-01-04     -3      7      2      7     11     -6      7     -5     -6
# 2029-01-05      3      8      1     -3      3     -3      8      8     11
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2029-09-23      9      7     -4     -6     -2      7      1      1     11
# 2029-09-24      2      6      9      4      9     -5      0     -3      9
# 2029-09-25     -3     -1      3      9     -5     -4      4      1      5
# 2029-09-26     -1     -1      2     12     10      4      9     -6      7
# 2029-09-27      1      9      3      3     -5     -2      8     10      7
#
#             Col_10  ...  Col_41  Col_42  Col_43  Col_44  Col_45  Col_46  \
# 2029-01-01       9  ...      12       7       5       6       3      -2
# 2029-01-02      12  ...      -6       5       5       3       6       6
# 2029-01-03       0  ...      10      11      11      -6       2      -7
# 2029-01-04      -7  ...       3       7       1       0       7      10
# 2029-01-05       5  ...      12      -5      -3       4       7      -1
# ...            ...  ...     ...     ...     ...     ...     ...     ...
# 2029-09-23      -3  ...       0      12       8      10      12      12
# 2029-09-24       7  ...       0       6      -3      -1       1      10
# 2029-09-25      12  ...       8       3       0       9       7       5
# 2029-09-26      -4  ...      -6      11       9      10       6       8
# 2029-09-27      -3  ...       8       3      -5      -3       7      12
#
#             Col_47  Col_48  Col_49  Col_50
# 2029-01-01      -5      11       9       4
# 2029-01-02      -3      -7      -6      12
# 2029-01-03      -3      11      -6      11
# 2029-01-04       9       8      -6      -5
# 2029-01-05      -7       3       6      12
# ...            ...     ...     ...     ...
# 2029-09-23       7       1      -2       5
# 2029-09-24      -7       7       2      -4
# 2029-09-25      11       4       6       9
# 2029-09-26      -4       6      10       2
# 2029-09-27      -7       5       9      -4
#
# [270 rows x 50 columns]
#             Col_1  Col_2  Col_3  Col_4  Col_5  Col_6  Col_7  Col_8  Col_9  \
# 2029-01-01      9     11      3     -7      2      9     -5      8      4
# 2029-01-02      4     12     -4     11     -3      4     -6      3     11
# 2029-01-03      5      8      9      9      7     -4     -1      3      8
# 2029-01-04     -3      7      2      7     11     -6      7     -5     -6
# 2029-01-05      3      8      1     -3      3     -3      8      8     11
#
#             Col_10  ...  Col_41  Col_42  Col_43  Col_44  Col_45  Col_46  \
# 2029-01-01       9  ...      12       7       5       6       3      -2
# 2029-01-02      12  ...      -6       5       5       3       6       6
# 2029-01-03       0  ...      10      11      11      -6       2      -7
# 2029-01-04      -7  ...       3       7       1       0       7      10
# 2029-01-05       5  ...      12      -5      -3       4       7      -1
#
#             Col_47  Col_48  Col_49  Col_50
# 2029-01-01      -5      11       9       4
# 2029-01-02      -3      -7      -6      12
# 2029-01-03      -3      11      -6      11
# 2029-01-04       9       8      -6      -5
# 2029-01-05      -7       3       6      12
#
# [5 rows x 50 columns]

# %%
# Sort DataFrame by the values in Column 3 using .sort_values
df_rnd.sort_values(by = 'Col_3', ascending = False).head()
# Out:
#             Col_1  Col_2  Col_3  Col_4  Col_5  Col_6  Col_7  Col_8  Col_9  \
# 2029-03-07     -6     -4     12      4      6     -5      5      6     -4
# 2029-02-10     12     -5     12      6      0      5      5     12     -1
# 2029-08-20     -1      9     12     11     10     11      7     -5      6
# 2029-03-30      3      5     12      7     -5      0      0     10      6
# 2029-07-01     -2      5     12     -2     11     -4     -6     -6      6
#
#             Col_10  ...  Col_41  Col_42  Col_43  Col_44  Col_45  Col_46  \
# 2029-03-07      10  ...       6       7       7       6       8      -7
# 2029-02-10       4  ...       6       8       7      -1      12       3
# 2029-08-20      -4  ...      -6       9       5      10       6       5
# 2029-03-30      12  ...       1      10       1       0      -6       3
# 2029-07-01      -5  ...       8      11       7      -4      11       6
#
#             Col_47  Col_48  Col_49  Col_50
# 2029-03-07       3      -4       2      12
# 2029-02-10       6      -7      11      -6
# 2029-08-20      -7      -2       9      -4
# 2029-03-30       3       0       8       7
# 2029-07-01       1      10      10      -5
#
# [5 rows x 50 columns]

# %%
# Create a copy of the df
# Replace all negative numbers  by 'Not a Number' (np.nan)
# Replace all numbers > 10  by 'Infinite' (np.inf)

df_cpy = df_rnd.copy()

# Nan
df_cpy[df_cpy < 0] = np.nan

# Inf
df_cpy[df_cpy > 10] = np.inf
display(df_cpy.head())
# Out:
#             Col_1  Col_2  Col_3  Col_4  Col_5  Col_6  Col_7  Col_8  Col_9  \
# 2029-01-01    9.0    inf    3.0    NaN    2.0    9.0    NaN    8.0    4.0
# 2029-01-02    4.0    inf    NaN    inf    NaN    4.0    NaN    3.0    inf
# 2029-01-03    5.0    8.0    9.0    9.0    7.0    NaN    NaN    3.0    8.0
# 2029-01-04    NaN    7.0    2.0    7.0    inf    NaN    7.0    NaN    NaN
# 2029-01-05    3.0    8.0    1.0    NaN    3.0    NaN    8.0    8.0    inf
#
#             Col_10  ...  Col_41  Col_42  Col_43  Col_44  Col_45  Col_46  \
# 2029-01-01     9.0  ...     inf     7.0     5.0     6.0     3.0     NaN
# 2029-01-02     inf  ...     NaN     5.0     5.0     3.0     6.0     6.0
# 2029-01-03     0.0  ...    10.0     inf     inf     NaN     2.0     NaN
# 2029-01-04     NaN  ...     3.0     7.0     1.0     0.0     7.0    10.0
# 2029-01-05     5.0  ...     inf     NaN     NaN     4.0     7.0     NaN
#
#             Col_47  Col_48  Col_49  Col_50
# 2029-01-01     NaN     inf     9.0     4.0
# 2029-01-02     NaN     NaN     NaN     inf
# 2029-01-03     NaN     inf     NaN     inf
# 2029-01-04     9.0     8.0     NaN     NaN
# 2029-01-05     NaN     3.0     6.0     inf
#
# [5 rows x 50 columns]

# %%
# Verify the data type of the original dataframe
# Verify the data type of the new dataframe

display(df_rnd.dtypes.head())
display(df_cpy.dtypes.head())
# Out:
# Col_1    int64
# Col_2    int64
# Col_3    int64
# Col_4    int64
# Col_5    int64
# dtype: object
# Col_1    float64
# Col_2    float64
# Col_3    float64
# Col_4    float64
# Col_5    float64
# dtype: object

# %%
# Create histogram of the distribution of Nan values counted by column
import matplotlib.pyplot as plt
a = df_cpy.isna().sum() # To compute NaNs by Column
plt.hist(a, bins=16)
plt.show()
